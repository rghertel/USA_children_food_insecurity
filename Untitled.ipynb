# %%
import re
import pandas as pd

# %%
#import csv

food_desert = pd.read_csv('data/FoodAccessResearchAtlasData2019.csv', low_memory=False)

food_desert.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# ...

# %%
food_desert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72531 entries, 0 to 72530
# Columns: 147 entries, CensusTract to TractSNAP
# dtypes: float64(126), int64(19), object(2)
# memory usage: 81.3+ MB

# %%
#only keep important rows

food_desert = food_desert[['Pop2010', 'State','County','Urban','lakids1','lakids1share','lakids10','lakids10share']]
food_desert
# Out:
#        Pop2010    State           County  Urban  lakids1  lakids1share  \
# 0         1912  Alabama   Autauga County      1    504.0         26.33
# 1         2170  Alabama   Autauga County      1    406.0         18.69
# 2         3373  Alabama   Autauga County      1    416.0         12.34
# 3         4386  Alabama   Autauga County      1    346.0          7.89
# 4        10766  Alabama   Autauga County      1    715.0          6.64
# ...        ...      ...              ...    ...      ...           ...
# 72526     3326  Wyoming  Washakie County      0    716.0         21.52
# 72527     2665  Wyoming  Washakie County      1      NaN           NaN
# 72528     2542  Wyoming  Washakie County      1     30.0          1.17
# 72529     3314  Wyoming    Weston County      0    394.0         11.90
# 72530     3894  Wyoming    Weston County      1    341.0          8.76
#
#        lakids10  lakids10share
# 0           NaN            NaN
# 1           NaN            NaN
# ...

# %%
food_desert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72531 entries, 0 to 72530
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pop2010        72531 non-null  int64
#  1   State          72531 non-null  object
#  2   County         72531 non-null  object
#  3   Urban          72531 non-null  int64
#  4   lakids1        52542 non-null  float64
#  5   lakids1share   52542 non-null  float64
#  6   lakids10       7766 non-null   float64
#  7   lakids10share  7766 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 4.4+ MB

# %%
food_desert_counties = food_desert.groupby(['County','Urban','State']).sum().reset_index()

# %%
#Andrew- can I conclude that lakids1 & 10 / population gives an accurate share/%?
food_desert_counties = food_desert_counties.sort_values(['State','County'])
food_desert_counties.head(40)
# Out:
#                 County  Urban    State  Pop2010  lakids1  lakids1share  \
# 183     Autauga County      0  Alabama    25405   6333.0        125.08
# 184     Autauga County      1  Alabama    29166   3640.0        108.23
# 196     Baldwin County      0  Alabama    99521  20756.0        345.16
# 198     Baldwin County      1  Alabama    82744   9877.0        170.77
# 213     Barbour County      0  Alabama    20819   3460.0        114.76
# 215     Barbour County      1  Alabama     6638    241.0          8.20
# 335        Bibb County      0  Alabama    22915   4198.0         81.94
# 364      Blount County      0  Alabama    50272  11699.0        185.91
# 366      Blount County      1  Alabama     7050    876.0         12.42
# 512     Bullock County      0  Alabama     3812    867.0         45.87
# 513     Bullock County      1  Alabama     7102   1005.0         14.14
# 533      Butler County      0  Alabama    16530   2670.0        118.04
# ...
