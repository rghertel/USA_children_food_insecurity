# %%
import re
import pandas as pd

# %%
fi_counties_18 = pd.read_csv('../data/Map the Meal Gap data/MMG2020_2018county.csv')
fi_counties_18 = fi_counties_18[['State','County, State', '2018 Child food insecurity rate']]
fi_counties_18
# Out:
#      State               County, State 2018 Child food insecurity rate
# 0       AL     Autauga County, Alabama                          21.40%
# 1       AL     Baldwin County, Alabama                          16.90%
# 2       AL     Barbour County, Alabama                          32.00%
# 3       AL        Bibb County, Alabama                          20.90%
# 4       AL      Blount County, Alabama                          19.10%
# ...    ...                         ...                             ...
# 3137    WY  Sweetwater County, Wyoming                          15.40%
# 3138    WY       Teton County, Wyoming                           8.40%
# 3139    WY       Uinta County, Wyoming                          18.70%
# 3140    WY    Washakie County, Wyoming                          18.40%
# 3141    WY      Weston County, Wyoming                          22.30%
#
# [3142 rows x 3 columns]

# %%
fi_counties_18[['County','State']] = fi_counties_18['County, State'].str.split(', ', expand=True)
fi_counties_18
# Out:
#         State               County, State 2018 Child food insecurity rate  \
# 0     Alabama     Autauga County, Alabama                          21.40%
# 1     Alabama     Baldwin County, Alabama                          16.90%
# 2     Alabama     Barbour County, Alabama                          32.00%
# 3     Alabama        Bibb County, Alabama                          20.90%
# 4     Alabama      Blount County, Alabama                          19.10%
# ...       ...                         ...                             ...
# 3137  Wyoming  Sweetwater County, Wyoming                          15.40%
# 3138  Wyoming       Teton County, Wyoming                           8.40%
# 3139  Wyoming       Uinta County, Wyoming                          18.70%
# 3140  Wyoming    Washakie County, Wyoming                          18.40%
# 3141  Wyoming      Weston County, Wyoming                          22.30%
#
#                  County
# 0        Autauga County
# 1        Baldwin County
# ...

# %%
fi_counties_18.to_csv('../data/Map the Meal Gap data/fi_counties_2018.csv')
